# %% [markdown]
# <a href="https://colab.research.google.com/github/miajags/EMSC2010-W2-P1-u7496742/blob/main/EMSC2010_W2_P1_NB1_u7496742.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010_W2_P1_NB1
# ---
#
# *   Class: EMSC2010
# *   Week: 2
# *   Session: Practical 1
#
# ---
#
# From GitHub, you can open this notebook in Google Colab using the 'Open in Colab' button. Then:
#
# 1. Change the notebook name to include your U-number (e.g EMSC2010_W2_P1_NB1_uXXXXXXX.ipynb)
# 2. Save to Google Drive (*File* >>> *Save a copy in Drive*)
# 3. Do a small calculation in a cell (e.g. *1+1*)
#
# Your work will save automatically to Google Drive. Once you are ready:
#
# 4. Commit to GitHub (*File* >>> *Save a copy in GitHub*)
# 5. Select the repository for your commit (same as your original repository)
# 6. Give a brief commit message (e.g. 'my first test commit')
# 7. Check your GitHub repository, a copy of your notebook should be there.
#
# ---
#
# Because Google Drive is saving your work automatically, you don't need to commit all minor edits to GitHub. Rather commit when you want to archive a version of your notebook because you have completed a substantial task.

# %%
1+1
# Out:
# 2

# %%
2+8
# Out:
# 10

# %%
10+10-1 #hello I am testing
# Out:
# 19

# %%
5+5 #new line after my first copy to drive
# Out:
# 10
